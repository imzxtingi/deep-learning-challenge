# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN"])
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_types = application_df["APPLICATION_TYPE"].value_counts()
application_types
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_types[application_types < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_type = application_df["CLASSIFICATION"].value_counts()
classification_type
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_type.loc[(classification_type)>1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_type[classification_type < 800].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
name_types = application_df["NAME"].value_counts()
name_types
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
name_types.loc[(name_types)>5]
# Out:
# NAME
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# OLD OAK CLIFF CONSERVATION LEAGUE INC                 6
# AMERICAN NEPHROLOGY NURSES ASSOCIATION                6
# HUMBLE ISD EDUCATIONAL SUPPORT GROUPS INC             6
# PROFESSIONAL LOADMASTER ASSOCIATION                   6
# CBMC INC                                              6
# Name: count, Length: 354, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
names_to_replace = list(name_types[name_types < 5].index)

# Replace in dataframe
for ntr in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(ntr,"Other")

# Check to make sure replacement was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                                                19803
# PARENT BOOSTER USA INC                                                1260
# TOPS CLUB INC                                                          765
# UNITED STATES BOWLING CONGRESS INC                                     700
# WASHINGTON STATE UNIVERSITY                                            492
#                                                                      ...
# GUILDS OF THE SANTA FE OPERA INC                                         5
# FAMILY MOTOR COACH ASSOCIATION                                           5
# JAMESTOWN SOCIETY                                                        5
# MOST WORSHIPFUL PRINCE HALL GRAND LODGE OF FREE & ACCEPTED MASONS        5
# PTA HAWAII CONGRESS                                                      5
# Name: count, Length: 403, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df)
application_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_AACE INTERNATIONAL  \
# 0       1     5000              1                    False
# 1       1   108590              1                    False
# 2       1     5000              0                    False
# 3       1     6692              1                    False
# 4       1   142590              1                    False
#
#    NAME_ACE MENTOR PROGRAM OF AMERICA INC  NAME_ACTS MINISTRY  \
# 0                                   False               False
# 1                                   False               False
# 2                                   False               False
# 3                                   False               False
# 4                                   False               False
#
#    NAME_ACTS MISSIONS  \
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
#
#    NAME_AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_AIR FORCE ASSOCIATION  NAME_ALABAMA FEDERATION OF WOMENS CLUBS  ...  \
# 0                       False                                    False  ...
# 1                       False                                    False  ...
# 2                       False                                    False  ...
# 3                       False                                    False  ...
# 4                       False                                    False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 447 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies["IS_SUCCESSFUL"]
X = application_dummies.drop(columns="IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=446))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=40, activation="sigmoid"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 80)                35760
#
#  dense_9 (Dense)             (None, 60)                4860
#
#  dense_10 (Dense)            (None, 40)                2440
#
#  dense_11 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 43101 (168.36 KB)
# Trainable params: 43101 (168.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 4s 3ms/step - loss: 0.4830 - accuracy: 0.7676
# Epoch 2/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4346 - accuracy: 0.7935
# Epoch 3/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4289 - accuracy: 0.7966
# Epoch 4/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4258 - accuracy: 0.7968
# Epoch 5/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4244 - accuracy: 0.7957
# Epoch 6/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4218 - accuracy: 0.7989
# Epoch 7/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4203 - accuracy: 0.8000
# Epoch 8/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4193 - accuracy: 0.8007
# Epoch 9/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4187 - accuracy: 0.8004
# Epoch 10/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4174 - accuracy: 0.8010
# Epoch 11/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4172 - accuracy: 0.8011
# Epoch 12/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4168 - accuracy: 0.8010
# Epoch 13/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4158 - accuracy: 0.8021
# Epoch 14/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4148 - accuracy: 0.8019
# Epoch 15/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4152 - accuracy: 0.8021
# Epoch 16/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4137 - accuracy: 0.8029
# Epoch 17/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4130 - accuracy: 0.8035
# Epoch 18/50
# 804/804 [==============================] - 4s 4ms/step - loss: 0.4133 - accuracy: 0.8035
# Epoch 19/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4127 - accuracy: 0.8023
# Epoch 20/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4114 - accuracy: 0.8032
# Epoch 21/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4111 - accuracy: 0.8034
# Epoch 22/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4105 - accuracy: 0.8031
# Epoch 23/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4099 - accuracy: 0.8047
# Epoch 24/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4100 - accuracy: 0.8047
# Epoch 25/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4095 - accuracy: 0.8046
# Epoch 26/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4087 - accuracy: 0.8039
# Epoch 27/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4086 - accuracy: 0.8050
# Epoch 28/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4079 - accuracy: 0.8059
# Epoch 29/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4078 - accuracy: 0.8059
# Epoch 30/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4075 - accuracy: 0.8047
# Epoch 31/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4069 - accuracy: 0.8050
# Epoch 32/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4064 - accuracy: 0.8052
# Epoch 33/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4058 - accuracy: 0.8070
# Epoch 34/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4055 - accuracy: 0.8070
# Epoch 35/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4054 - accuracy: 0.8067
# Epoch 36/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4047 - accuracy: 0.8068
# Epoch 37/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4047 - accuracy: 0.8061
# Epoch 38/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4048 - accuracy: 0.8072
# Epoch 39/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4046 - accuracy: 0.8068
# Epoch 40/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4039 - accuracy: 0.8066
# Epoch 41/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4034 - accuracy: 0.8066
# Epoch 42/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4033 - accuracy: 0.8076
# Epoch 43/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4031 - accuracy: 0.8076
# Epoch 44/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4030 - accuracy: 0.8084
# Epoch 45/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4022 - accuracy: 0.8081
# Epoch 46/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4022 - accuracy: 0.8084
# Epoch 47/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4024 - accuracy: 0.8069
# Epoch 48/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4020 - accuracy: 0.8080
# Epoch 49/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4011 - accuracy: 0.8085
# Epoch 50/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4012 - accuracy: 0.8082

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4578 - accuracy: 0.7922 - 620ms/epoch - 2ms/step
# Loss: 0.45779427886009216, Accuracy: 0.7921866178512573

# %%
# Export our model to HDF5 file
nn_model.save('HDF5_files/AlphabetSoupCharity_Optimization.h5')
